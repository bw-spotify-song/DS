# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# Importing DataSet
df = pd.read_csv(r"C:\Users\Terrence Malone\Desktop\DS_UNIT_4_BUILD\data.csv")
df.shape
# Out:
# (169909, 19)

# %%
df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# ...

# %%
df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
dictionary = df[['artists', 'id', 'name', 'year']]

# %%
df.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  169909.000000  169909.000000  1.699090e+05  169909.000000
# mean        0.493214       0.538150  2.314062e+05       0.488593
# std         0.376627       0.175346  1.213219e+05       0.267390
# min         0.000000       0.000000  5.108000e+03       0.000000
# 25%         0.094500       0.417000  1.710400e+05       0.263000
# 50%         0.492000       0.548000  2.086000e+05       0.481000
# 75%         0.888000       0.667000  2.629600e+05       0.710000
# max         0.996000       0.988000  5.403500e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  169909.000000     169909.000000  169909.000000  169909.000000
# mean        0.084863          0.161937       5.200519       0.206690
# std         0.278679          0.309329       3.515257       0.176796
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
# Drop columns for training
df = df.drop(columns=['artists', 'id', 'name'])

# %%
df = df.drop(columns=['release_date'])

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.995         0.708       158648  0.1950         0
# 1         0.994         0.379       282133  0.0135         0
# 2         0.604         0.749       104300  0.2200         0
# 3         0.995         0.781       180760  0.1300         0
# 4         0.990         0.210       687733  0.2040         0
#
#    instrumentalness  key  liveness  loudness  mode  popularity  speechiness  \
# 0             0.563   10    0.1510   -12.428     1           0       0.0506
# 1             0.901    8    0.0763   -28.454     1           0       0.0462
# 2             0.000    5    0.1190   -19.924     0           0       0.9290
# 3             0.887    1    0.1110   -14.734     0           0       0.0926
# 4             0.908   11    0.0980   -16.829     1           1       0.0424
#
#      tempo  valence  year
# 0  118.469   0.7790  1928
# 1   83.972   0.0767  1928
# 2  107.177   0.8800  1928
# 3  108.003   0.7200  1928
# ...

# %%
dictionary.head
# Out:
# <bound method NDFrame.head of                                          artists                      id  \
# 0                            ['Carl Woitschach']  6KbQ3uYMLKb5jDxLF7wYDD
# 1       ['Robert Schumann', 'Vladimir Horowitz']  6KuQTIu1KoTTkLXKrwlLPV
# 2                        ['Seweryn Goszczyński']  6L63VW0PibdM1HDSBoqnoM
# 3                           ['Francisco Canaro']  6M94FkXd15sOAOQYRnWPN8
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']  6N6tiFZ9vLTSOIxkj8qKrd
# ...                                          ...                     ...
# 169904                    ['DripReport', 'Tyga']  4KppkflX7I3vJQk7urOJaS
# 169905        ['Leon Bridges', 'Terrace Martin']  1ehhGlTvjtHo2e4xJFB0SZ
# 169906                     ['Kygo', 'Oh Wonder']  52eycxprLhK3lPcRLbQiVk
# 169907             ['Cash Cash', 'Andy Grammer']  3wYOGJYD31sLRmBgCvWxa4
# 169908                        ['Ingrid Andress']  60RFlt48hm0l4Fu0JoccOl
#
#                                                  name  year
# ...

# %%
# Scaling Data
scaler = StandardScaler()
df = scaler.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split
X_train, y_train = train_test_split(df, train_size=.33)

# %%
X_test.shape, y_test.shape
# Out:
# ((127431,), (42478,))

# %%
X_train.shape, y_train.shape
# Out:
# ((56069, 15), (113840, 15))

# %%
# Model Building

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.optimizers import SGD

opt=SGD(learning_rate=.01)

model = Sequential([Dense(32, activation='softmax', input_dim=10),
                    Dense(32, activation='relu', input_dim=10),
                    Dense(32, activation='relu'),
                    Dense(3, activation='softplus')
])

model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_105 (Dense)            (None, 32)                352
# _________________________________________________________________
# dense_106 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_107 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_108 (Dense)            (None, 3)                 99
# ...
# Total params: 2,563
# Trainable params: 2,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-345-bab577512e44> in <module>
# ----> 1 model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ...
