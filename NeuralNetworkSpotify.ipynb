# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
# Importing DataSet
df = pd.read_csv('/Users/terrenceam22/Downloads/670134-1261707-bundle-archive-2/data.csv')

# %%
df.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# ...

# %%
df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
# Holding Test Set
test = df[['artists']]
df.drop(columns=['artists'])
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 0             0.9950         0.708       158648  0.1950         0
# 1             0.9940         0.379       282133  0.0135         0
# 2             0.6040         0.749       104300  0.2200         0
# 3             0.9950         0.781       180760  0.1300         0
# 4             0.9900         0.210       687733  0.2040         0
# ...              ...           ...          ...     ...       ...
# 169904        0.1730         0.875       163800  0.4430         1
# 169905        0.0167         0.719       167468  0.3850         0
# 169906        0.5380         0.514       180700  0.5390         0
# 169907        0.0714         0.646       167308  0.7610         0
# 169908        0.1090         0.512       214787  0.4280         0
#
#                             id  instrumentalness  key  liveness  loudness  \
# 0       6KbQ3uYMLKb5jDxLF7wYDD          0.563000   10    0.1510   -12.428
# ...

# %%
train, val = train_test_split(df, test_size=.5)

# %%
target = 'artists'
# Features
features = ['danceability', 'energy', 'loudness', 'speechiness']

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = train[features]
print(features)
# Out:
# ['danceability', 'energy', 'loudness', 'speechiness']

# %%
test
# Out:
#                                          artists
# 0                            ['Carl Woitschach']
# 1       ['Robert Schumann', 'Vladimir Horowitz']
# 2                        ['Seweryn Goszczyński']
# 3                           ['Francisco Canaro']
# 4       ['Frédéric Chopin', 'Vladimir Horowitz']
# ...                                          ...
# 169904                    ['DripReport', 'Tyga']
# 169905        ['Leon Bridges', 'Terrace Martin']
# 169906                     ['Kygo', 'Oh Wonder']
# 169907             ['Cash Cash', 'Andy Grammer']
# 169908                        ['Ingrid Andress']
#
# [169909 rows x 1 columns]

# %%
import category_encoders as ce

encoder = ce.OneHotEncoder(use_cat_names=True)
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)

# %%
X_train.shape, y_train.shape
# Out:
# ((84954, 4), (84954,))

# %%
# X_train = X_train.astype('float32')
# y_train = y_train.astype('float32')
# y_train = encoder.fit_transform(y_train)
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_train = le.fit_transform(y_train)
# Out:
# /Users/terrenceam22/.local/share/virtualenvs/terrenceam22-N_X-jW-K/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_train = y_train.astype('float32')

# %%
# y_val = le.fit_transform(y_val)
y_val = y_val.astype('float32')
X_val = X_val.astype('float32')

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM, Conv2D, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import SGD
# opt=SGD(learning_rate=.01)


model = Sequential([Dense(32, input_dim=4, activation='selu'),
                    Dense(32, activation='relu', kernel_constraint=max_norm(2,)),
                    Dense(32, activation='relu'),
                    Dense(24, activation='relu'),
                    Dense(20, activation='relu'),
                    Dense(1, activation='sigmoid')
                    
])

model.compile(optimizer='nadam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_41 (Dense)             (None, 32)                160
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_44 (Dense)             (None, 24)                792
# _________________________________________________________________
# dense_45 (Dense)             (None, 20)                500
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 21
# ...
# Total params: 3,585
# Trainable params: 3,585
# Non-trainable params: 0
# ...

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 2655/2655 [==============================] - 5s 2ms/step - loss: 0.0013 - accuracy: 1.1771e-05 - val_loss: 0.0013 - val_accuracy: 2.3542e-05
# Epoch 2/10
# 2655/2655 [==============================] - 5s 2ms/step - loss: 0.0013 - accuracy: 1.1771e-05 - val_loss: 0.0013 - val_accuracy: 2.3542e-05
# Epoch 3/10
# 2655/2655 [==============================] - 6s 2ms/step - loss: 0.0013 - accuracy: 1.1771e-05 - val_loss: 0.0013 - val_accuracy: 2.3542e-05
# Epoch 4/10
#    1/2655 [..............................] - ETA: 0s - loss: 0.0012 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-e72ee82282ed> in <module>
# ----> 1 model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
#
# ...

# %%
X_test
# Out:
#         danceability  energy  loudness  speechiness
# 14199          0.367  0.7760    -6.878       0.1050
# 38940          0.541  0.9100    -6.289       0.1160
# 110884         0.569  0.5400   -11.022       0.0365
# 47045          0.299  0.6070    -6.808       0.0432
# 156273         0.628  0.7830    -7.799       0.0323
# ...              ...     ...       ...          ...
# 41216          0.560  0.0855   -18.577       0.1350
# 159498         0.867  0.3840    -8.334       0.2680
# 35186          0.433  0.1380   -15.738       0.0402
# 37609          0.570  0.1260   -17.349       0.2180
# 122754         0.641  0.7010   -14.348       0.0346
#
# [84954 rows x 4 columns]

# %%
new_input = [[-1, 0.367]]
predict = model.predict(new_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-9c464a849bb3> in <module>
#       1 new_input = [[-1, 0.367]]
# ----> 2 predict = model.predict(new_input)
#
# ~/.local/share/virtualenvs/terrenceam22-N_X-jW-K/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# ~/.local/share/virtualenvs/terrenceam22-N_X-jW-K/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1266           for step in data_handler.steps():
# ...
